# %% [markdown]
# ![title](Header__0001_9.png)
# ___
# # Chapter 9 - Web-based Data Visualizations with Plotly
# ## Segment 2 - Statistical charts
# #### Setting up to use Plotly within Jupyter

# %%
import numpy as np
import pandas as pd

import cufflinks as cf

import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go

import sklearn
from sklearn.preprocessing import StandardScaler

# %%
tls.set_credentials_file(username='ddzmitry', api_key='cJyBVR0Xdkr0mAUf02UP')

# %% [markdown]
# ### Creating histograms
# #### Make a histogram from a pandas Series object

# %%
address = r'C:\Users\ddzmi\Desktop\DataViz\Ex_Files_Python_Data_Science_EssT\Exercise Files\Ch09\09_01\mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars.mpg

mpg.iplot(kind='histogram', filename='simple-histogram-chart')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ddzmitry/14.embed" height="525px" width="100%"></iframe>

# %%
cars_data = cars.iloc[:,[1,3,4]].values

cars_data_std = StandardScaler().fit_transform(cars_data)

cars_select = pd.DataFrame(cars_data_std)
cars_select.columns = ['mpg', 'disp', 'hp']

cars_select.iplot(kind='histogram', filename='multiple-histogram-chart')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ddzmitry/16.embed" height="525px" width="100%"></iframe>

# %%
cars_select.iplot(kind='histogram', subplots=True, filename='subplot-histograms')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ddzmitry/18.embed" height="525px" width="100%"></iframe>

# %%
cars_select.iplot(kind='histogram', subplots=True, shape=(3,1), filename='subplot-histograms')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ddzmitry/18.embed" height="525px" width="100%"></iframe>

# %%
cars_select.iplot(kind='histogram', subplots=True, shape=(1, 3), filename='subplot-histograms')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ddzmitry/18.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Creating box plots

# %%
cars_select.iplot(kind='box', filename='box-plots')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ddzmitry/20.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Creating scatter plots

# %%
fig = {'data':[{'x':cars_select.mpg, 'y':cars_select.disp, 'mode':'markers','name':'mpg'},
              {'x':cars_select.hp, 'y':cars_select.disp,'mode':'markers', 'name':'hp'}]
      , 'layout':{'xaxis':{'title':'Data Defined'}, 'yaxis':{'title':'Standardized Displacement'}}}
py.iplot(fig, filename='grouped-scatter-plot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ddzmitry/22.embed" height="525px" width="100%"></iframe>
